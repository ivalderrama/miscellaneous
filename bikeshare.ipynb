# %%
import numpy as np
import pandas as pd
import time

# %%
CITY_DATA = { 'chicago': 'workspace/chicago.csv',
              'new york city': 'workspace/new_york_city.csv',
              'washington': 'workspace/washington.csv' }

# %%
def get_filters():
    """
    Asks user to specify a city, month, and day to analyze.

    Returns:
        (str) city - name of the city to analyze
        (str) month - name of the month to filter by, or "all" to apply no month filter
        (str) day - name of the day of week to filter by, or "all" to apply no day filter
    """
    print('Hello! Let\'s explore some US bikeshare data!')
    city = None
    month = None
    day = None

    city_dict = {'1': 'chicago', '2': 'new york city', '3': 'washington'}
    month_dict = {'1': 'january', '2': 'february', '3': 'march', '4': 'april', '5': 'may', '6': 'june', '0': 'all' }
    day_dict = {
        '1': 'monday', 
        '2': 'tuesday', 
        '3': 'wednesday', 
        '4': 'thursday', 
        '5': 'friday', 
        '6': 'saturday',
        '7': 'sunday',
        '0': 'all'
    }

    while True:
        print(
            "Please select a city by number:\n \
            1=Chicago; 2=New York; 3=Washington"
        )
        city_input = input("Enter your chosen city: ")

        if city_input in city_dict:
            city = city_dict[city_input]
            break
        else:
            print("You have entered an invalid option")

    while True:
        print(
            "Please select your month by number:\n \
            1=January; 2=February; 3=March; 4=April; 5=May; 6=June; 0=All"
        )
        month_input = input("Enter your month: ")

        if month_input in month_dict:
            month = month_dict[month_input]
            break
        else:
            print("You have entered an invalid option")

    while True:
        print(
            "Please select your day by number:\n \
            1=Monday; 2=Tuesday; 3=Wednesday; 4=Thursday; 5=Friday; 6=Saturday; 7=Sunday; 0=All"
        )
        day_input = input("Enter your day: ")

        if day_input in day_dict:
            day = day_dict[day_input]
            break
        else:
            print("You have entered an invalid option")

    print("You have selected the following: city={}, month={}, day={}".format(city, month, day))          
    print('-'*40)
    
    return city, month, day

# %%
def load_data(city, month, day):
    """
    Loads data for the specified city and filters by month and day if applicable.

    Args:
        (str) city - name of the city to analyze
        (str) month - name of the month to filter by, or "all" to apply no month filter
        (str) day - name of the day of week to filter by, or "all" to apply no day filter
    Returns:
        df - Pandas DataFrame containing city data filtered by month and day
    """
    
    # Load data fiel into a dataframe
    df = pd.read_csv(CITY_DATA[city])
    
    # Convert the Start Time column to datatime
    df['Start Time'] = pd.to_datetime(df['Start Time'])
    
    # Convert the End Time column to datatime
    df['End Time'] = pd.to_datetime(df['End Time'])
    
    # Extract month and day of the week from Start Time to create new columns
    df['month'] = df['Start Time'].dt.month
    df['day_of_week'] = df['Start Time'].dt.weekday_name
    
    # Extract hour from from Start Time to create new column
    df['hour'] = df['Start Time'].dt.hour
    
    # Filter by month if applicable
    if month != 'all':
        # Use the index of the months list to get the corresponding int
        months = ['january', 'february', 'march', 'april', 'may', 'june']
        month = months.index(month) + 1
        
        # Filter by month to create new new dataframe
        df = df[df['month'] == month]
        
    # Filter by day of week if applicable
    if day != 'all':
        # Filter by day of week to create the new dataframe
        df = df[df['day_of_week'] == day.title()]

    return df

# %%
city, month, day = get_filters()
# Out:
# Hello! Let's explore some US bikeshare data!
# Please select a city by number:
#              1=Chicago; 2=New York; 3=Washington
# Enter your chosen city: 1
# 91      Subscriber    Male      1985.0      1     Tuesday    10
# 117     Subscriber    Male      1989.0      1     Tuesday    17
# 130     Subscriber    Male      1967.0      1     Tuesday    18
# 237     Subscriber  Female      1988.0      1     Tuesday    18
# 245     Subscriber    Male      1986.0      1     Tuesday     7
# 273     Subscriber    Male      1983.0      1     Tuesday    20
# 366     Subscriber    Male      1968.0      1     Tuesday    16
# 490     Subscriber  Female      1990.0      1     Tuesday    17
# 534     Subscriber    Male      1965.0      1     Tuesday    14
# 694     Subscriber    Male      1978.0      1     Tuesday    17
# 754     Subscriber    Male      1981.0      1     Tuesday     8
# 788     Subscriber    Male      1969.0      1     Tuesday    10
# 919       Customer     NaN         NaN      1     Tuesday     8
# 937     Subscriber    Male      1977.0      1     Tuesday    20
# 1031    Subscriber    Male      1971.0      1     Tuesday     8
# 1077    Subscriber  Female      1979.0      1     Tuesday     7
# 1243    Subscriber    Male      1951.0      1     Tuesday    14
# 1260    Subscriber    Male      1983.0      1     Tuesday    17
# 1334    Subscriber    Male      1969.0      1     Tuesday    21
# 1379    Subscriber  Female      1984.0      1     Tuesday    15
# 1385    Subscriber    Male      1978.0      1     Tuesday     8
# 1399    Subscriber    Male      1992.0      1     Tuesday    19
# 1402    Subscriber    Male      1965.0      1     Tuesday     9
# 1502    Subscriber  Female      1964.0      1     Tuesday    11
# 1725    Subscriber  Female      1971.0      1     Tuesday     7
# 1751    Subscriber    Male      1970.0      1     Tuesday     8
# 1796    Subscriber    Male      1991.0      1     Tuesday    16
# 1800    Subscriber    Male      1959.0      1     Tuesday     4
# 1851    Subscriber    Male      1993.0      1     Tuesday    18
# ...            ...     ...         ...    ...         ...   ...
# 297593  Subscriber    Male      1971.0      1     Tuesday    16
# 297671  Subscriber    Male      1982.0      1     Tuesday    16
# 297823  Subscriber  Female      1992.0      1     Tuesday    14
# 297853  Subscriber    Male      1967.0      1     Tuesday     6
# 297855  Subscriber    Male      1988.0      1     Tuesday    16
# 297896  Subscriber    Male      1969.0      1     Tuesday    10
# 297957  Subscriber    Male      1975.0      1     Tuesday     6
# 298084  Subscriber    Male      1997.0      1     Tuesday    16
# 298330  Subscriber  Female      1984.0      1     Tuesday     9
# 298389  Subscriber  Female      1968.0      1     Tuesday    14
# 298474  Subscriber    Male      1986.0      1     Tuesday     8
# 298494  Subscriber    Male      1981.0      1     Tuesday     9
# 298499  Subscriber    Male      1976.0      1     Tuesday    18
# 298518  Subscriber    Male      1976.0      1     Tuesday    17
# 298532  Subscriber    Male      1967.0      1     Tuesday    23
# 298613  Subscriber    Male      1972.0      1     Tuesday    18
# 298871  Subscriber    Male      1983.0      1     Tuesday    11
# 298927  Subscriber  Female      1965.0      1     Tuesday    18
# 299116  Subscriber  Female      1989.0      1     Tuesday     8
# 299119  Subscriber    Male      1987.0      1     Tuesday    11
# 299248  Subscriber    Male      1984.0      1     Tuesday    10
# 299372  Subscriber    Male      1965.0      1     Tuesday    14
# 299443  Subscriber    Male      1960.0      1     Tuesday    14
# 299466  Subscriber  Female      1985.0      1     Tuesday    16
# 299535  Subscriber    Male      1969.0      1     Tuesday    17
# 299603  Subscriber  Female      1983.0      1     Tuesday     8
# 299738  Subscriber    Male      1985.0      1     Tuesday     7
# 299920  Subscriber    Male      1988.0      1     Tuesday    17
# 299958  Subscriber  Female      1966.0      1     Tuesday    11
# 299972  Subscriber  Female      1978.0      1     Tuesday     8
#
# [4527 rows x 12 columns]

# %%
def time_stats(df):
    """Displays statistics on the most frequent times of travel."""

    print('\nCalculating The Most Frequent Times of Travel...\n')
    start_time = time.time()

    # TO DO: display the most common month
    popular_month = df['month'].mode()[0]
    print("Most common month:", popular_month)

    # TO DO: display the most common day of week
    popular_day = df['day_of_week'].mode()[0]
    print("Most common day of the week:", popular_day)

    # TO DO: display the most common start hour
    popular_hour = df['hour'].mode()[0]
    print("Most common hour:", popular_hour)
    
    print("\nThis took %s seconds." % (time.time() - start_time))
    print('-'*40)

# %%
time_stats(df)
# Out:
# Calculating The Most Frequent Times of Travel...
#
# Most common month: 1
# Most common day of the week: Tuesday
# Most common hour: 17
#
# This took 0.0048940181732177734 seconds.
# ----------------------------------------

# %%
def station_stats(df):
    """Displays statistics on the most popular stations and trip."""

    print('\nCalculating The Most Popular Stations and Trip...\n')
    start_time = time.time()

    # TO DO: display most commonly used start station
    popular_start_station = df['Start Station'].mode()[0]
    print("Most common start station: {}".format(popular_start_station))

    # TO DO: display most commonly used end station
    popular_end_station = df['End Station'].mode()[0]
    print("Most common end station: {}".format(popular_end_station))

    # TO DO: display most frequent combination of start station and end station trip
    popular_start_end_station = df[['Start Station', 'End Station']].mode().loc[0]
    print("Most frequent combination of start station and end station trip: \n{}".format(popular_start_end_station))

    print("\nThis took %s seconds." % (time.time() - start_time))
    print('-'*40)

# %%
station_stats(df)
# Out:
# Calculating The Most Popular Stations and Trip...
#
# Most common start station: Clinton St & Washington Blvd
# Most common end station: Clinton St & Washington Blvd
# Most frequent combination of start station and end station trip:
# Start Station    Clinton St & Washington Blvd
# End Station      Clinton St & Washington Blvd
# Name: 0, dtype: object
#
# This took 0.009011030197143555 seconds.
# ----------------------------------------

# %%
def trip_duration_stats(df):
    """Displays statistics on the total and average trip duration."""

    print('\nCalculating Trip Duration...\n')
    start_time = time.time()

    # TO DO: display total travel time
    total_travel_time = df['Trip Duration'].sum()
    print(f"Total tavel time: {total_travel_time}")

    # TO DO: display mean travel time
    avg_travel_time = df['Trip Duration'].mean()
    print(f"Average travel time: {avg_travel_time}")


    print("\nThis took %s seconds." % (time.time() - start_time))
    print('-'*40)

# %%
trip_duration_stats(df)
# Out:
# Calculating Trip Duration...
#
# Total tavel time: 2701700
# Average travel time: 596.79699580296
#
# This took 0.0012447834014892578 seconds.
# ----------------------------------------

# %%
def user_stats(df):
    """Displays statistics on bikeshare users."""

    try:
        print('\nCalculating User Stats...\n')
        start_time = time.time()

        # TO DO: Display counts of user types
        user_type_counts = df['User Type'].value_counts()

        print("User type counts:\n{}".format(user_type_counts))
        print("\n")

        # TO DO: Display counts of gender
        gender_counts = df['Gender'].value_counts()

        print("Gender counts:\n{}".format(gender_counts))
        print("\n")

        # TO DO: Display earliest, most recent, and most common year of birth
        earliest_birth = df['Birth Year'].min()
        print(f"Earliest birth on record is: {earliest_birth}")

        popular_birth_year = df['Birth Year'].mode()[0]
        print(f"Most common birth year is: {popular_birth_year}")

        recent_birth = df['Birth Year'].max()
        print(f"Most recent birth on record is: {recent_birth}")
        
    except KeyError:
        print("Columns 'Gender' and 'Birth Year' do not exist for Wahsington city.")
        
    print("\nThis took %s seconds." % (time.time() - start_time))
    print('-'*40)

# %%
user_stats(df)
# Out:
# Calculating User Stats...
#
# User type counts:
# Subscriber    4467
# Customer        60
# Name: User Type, dtype: int64
#
#
# Gender counts:
# Male      3633
# Female     832
# Name: Gender, dtype: int64
#
#
# Earliest birth on record is: 1899.0
# Most common birth year is: 1989.0
# Most recent birth on record is: 1999.0
#
# This took 0.005365848541259766 seconds.
# ----------------------------------------

# %%
def display_raw_data(df):
    """Prompts the user to display data 5 rows at time"""
    
    print('\nCalculating Display of Raw Data...\n')
    start_time = time.time()
    
    user_input = None       
        
    for i in range(0, (df.shape[0]), 5):
        user_input = input("\nWould you like to view 5 rows or the next 5 rows of the dataframe? Enter yes or no.\n")
        
        if user_input == 'yes':
            print(f"\nDisplaying {i} to {i+5} rows of the dataframe")
            print(df[i:i+5])
        else:
            print('Thank you! Have a nice day!')
            break
    
    print("\nThis took %s seconds." % (time.time() - start_time))
    print('-'*40)

# %%
display_raw_data(df)
# Out:
# Calculating Display of Raw Data...
#
#
# Would you like to view 5 rows or the next 5 rows of the dataframe? Enter yes or no.
# y
# Thank you! Have a nice day!
#
# This took 3.9769041538238525 seconds.
# ----------------------------------------

# %%
def main():
    while True:
        city, month, day = get_filters()
        df = load_data(city, month, day)

        time_stats(df)
        station_stats(df)
        trip_duration_stats(df)
        user_stats(df)
        display_raw_data(df)

        restart = input('\nWould you like to restart? Enter yes or no.\n')
        if restart.lower() != 'yes':
            break


if __name__ == "__main__":
    main()
# Out:
# Hello! Let's explore some US bikeshare data!
# Please select a city by number:
#              1=Chicago; 2=New York; 3=Washington
# Enter your chosen city: 3
# Please select your month by number:
#              1=January; 2=February; 3=March; 4=April; 5=May; 6=June; 0=All
# Enter your month: 0
# Please select your day by number:
#              1=Monday; 2=Tuesday; 3=Wednesday; 4=Thursday; 5=Friday; 6=Saturday; 7=Sunday; 0=All
# Enter your day: 0
# You have selected the following: city=washington, month=all, day=all
# ----------------------------------------
#
# Calculating The Most Frequent Times of Travel...
#
# Most common month: 6
# Most common day of the week: Wednesday
# Most common hour: 8
#
# This took 0.02575993537902832 seconds.
# ----------------------------------------
#
# Calculating The Most Popular Stations and Trip...
#
# Most common start station: Columbus Circle / Union Station
# Most common end station: Columbus Circle / Union Station
# Most frequent combination of start station and end station trip:
# Start Station    Columbus Circle / Union Station
# End Station      Columbus Circle / Union Station
# Name: 0, dtype: object
#
# This took 0.14134907722473145 seconds.
# ----------------------------------------
#
# Calculating Trip Duration...
#
# Total tavel time: 371183985.484
# Average travel time: 1237.2799516133334
#
# This took 0.0024750232696533203 seconds.
# ----------------------------------------
#
# Calculating User Stats...
#
# User type counts:
# Subscriber    220786
# Customer       79214
# Name: User Type, dtype: int64
#
#
# Columns 'Gender' and 'Birth Year' do not exist for Wahsington city.
#
# This took 0.020931720733642578 seconds.
# ----------------------------------------
#
# Calculating Display of Raw Data...
#
#
# Would you like to view 5 rows or the next 5 rows of the dataframe? Enter yes or no.
# yes
#
# Displaying 0 to 5 rows of the dataframe
#    Unnamed: 0          Start Time            End Time  Trip Duration  \
# 0     1621326 2017-06-21 08:36:34 2017-06-21 08:44:43        489.066
# 1      482740 2017-03-11 10:40:00 2017-03-11 10:46:00        402.549
# 2     1330037 2017-05-30 01:02:59 2017-05-30 01:13:37        637.251
# 3      665458 2017-04-02 07:48:35 2017-04-02 08:19:03       1827.341
# 4     1481135 2017-06-10 08:36:28 2017-06-10 09:02:17       1549.427
#
#                                  Start Station                   End Station  \
# 0                         14th & Belmont St NW                15th & K St NW
# 1                   Yuma St & Tenley Circle NW  Connecticut Ave & Yuma St NW
# 2               17th St & Massachusetts Ave NW                 5th & K St NW
# 3             Constitution Ave & 2nd St NW/DOL    M St & Pennsylvania Ave NW
# 4  Henry Bacon Dr & Lincoln Memorial Circle NW         Maine Ave & 7th St SW
#
#     User Type  month day_of_week  hour
# 0  Subscriber      6   Wednesday     8
# 1  Subscriber      3    Saturday    10
# 2  Subscriber      5     Tuesday     1
# 3    Customer      4      Sunday     7
# 4  Subscriber      6    Saturday     8
#
# Would you like to view 5 rows or the next 5 rows of the dataframe? Enter yes or no.
# yes
#
# Displaying 5 to 10 rows of the dataframe
#    Unnamed: 0          Start Time            End Time  Trip Duration  \
# 5     1148202 2017-05-14 07:18:18 2017-05-14 07:24:56        398.000
# 6     1594275 2017-06-19 08:41:43 2017-06-19 09:00:08       1105.429
# 7     1601832 2017-06-20 05:54:42 2017-06-20 06:05:18        636.218
# 8      574182 2017-03-24 20:37:00 2017-03-24 20:42:00        328.530
# 9      327058 2017-02-20 21:12:00 2017-02-20 21:31:00       1188.090
#
#              Start Station                                        End Station  \
# 5            1st & K St SE  Eastern Market Metro / Pennsylvania Ave & 7th ...
# 6  Park Rd & Holmead Pl NW                                      8th & H St NW
# 7            1st & D St SE                      Potomac & Pennsylvania Ave SE
# 8           18th & R St NW                                     15th & P St NW
# 9    17th & Corcoran St NW                               Lynn & 19th St North
#
#     User Type  month day_of_week  hour
# 5  Subscriber      5      Sunday     7
# 6  Subscriber      6      Monday     8
# 7  Subscriber      6     Tuesday     5
# 8  Subscriber      3      Friday    20
# 9  Subscriber      2      Monday    21
#
# Would you like to view 5 rows or the next 5 rows of the dataframe? Enter yes or no.
# n
# Thank you! Have a nice day!
#
# This took 16.777462005615234 seconds.
# ----------------------------------------
#
# Would you like to restart? Enter yes or no.
# n
